# %% [markdown]
# # Data science capstone project

# %% [markdown]
# ### **Introduction**

# %% [markdown]
# Bangalore is the capital city of India's Southern state Karnataka.The center of India's high-tech industry, the city is also known for its parks and nightlife. similarly Chennai is the Capital of India's Southern State Tamil Nadu.It is a primary cultural, economic and educational center of south India. This report analyses whether both the cities are similar or they differ. this report analyses which city would be best for holiday spot.

# %% [markdown]
# ### **Data Section**

# %% [markdown]
# I will be using the  recreation centers for comparing. I would use Foursquare location data to cluster the data in the respective  city map and compare.
